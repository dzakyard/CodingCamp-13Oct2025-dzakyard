# %% [markdown]
# <a href="https://colab.research.google.com/github/dzakyard/CodingCamp-13Oct2025-dzakyard/blob/main/list.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
keranjang = ["Pensil", "Ballpoint", "Spidol", "Pensil"]

def lihat_keranjang():
    if len(keranjang) == 0:
        print("Keranjang masih kosong")
    else:
        for barang in keranjang:
            print(barang)

def tambah_barang():
    barang_baru = input("Masukkan barang : ")
    keranjang.append(barang_baru)
    print(f"{barang_baru} berhasil ditambahkan")

def update_barang():
    masukan = input("barang yang akan diganti : ")

    for i in range(len(keranjang)):
        if keranjang[i] == masukan:
            masukan_baru = input("Update nama barang : ")
            keranjang[i] = masukan_baru
            print("Berhasil update")
            return keranjang
            break
        else:
            print("Barang tidak valid")

def hapus_barang():
    masukan = input("barang yang akan dihapus : ")

    for barang in keranjang:
        if barang == masukan:
            keranjang.remove(barang)
            print(f"{masukan} Berhasil dihapus")
            break
        else:
            print("Barang tidak valid")

def menu():
    print()
    print("== TOKO ONLINE ==")
    print("1. Lihat Barang")
    print("2. Update Barang")
    print("3. Tambah Barang")
    print("4. Hapus Barang")
    print("5. Keluar")
    print()

while True:
    menu()

    pilihan_menu = int(input("Masukkan pilihan menu [1-5] : "))

    if pilihan_menu == 1:
        lihat_keranjang()
        input("Enter untuk kembali ke menu")

    elif pilihan_menu == 2:
        update_barang()
        input("Enter untuk kembali ke menu")

    elif pilihan_menu == 3:
        tambah_barang()
        input("Enter untuk kembali ke menu")

    elif pilihan_menu == 4:
        hapus_barang()
        input("Enter untuk kembali ke menu")

    elif pilihan_menu == 5:
        print("Keluar dari program")
        break

    else:
        pri
# Out:
# == TOKO ONLINE ==
# 1. Lihat Barang
# 2. Update Barang
# 3. Tambah Barang
# 4. Hapus Barang
# 5. Keluar
#
# Masukkan pilihan menu [1-5] : 4
# barang yang akan dihapus : Pensil
# Pensil Berhasil dihapus
# Enter untuk kembali ke menu
#
# == TOKO ONLINE ==
# 1. Lihat Barang
# 2. Update Barang
# 3. Tambah Barang
# 4. Hapus Barang
# 5. Keluar
#
# Masukkan pilihan menu [1-5] : 1
# Ballpoint
# Spidol
# Pensil
# Enter untuk kembali ke menu
#
# == TOKO ONLINE ==
# 1. Lihat Barang
# 2. Update Barang
# 3. Tambah Barang
# 4. Hapus Barang
# 5. Keluar
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-984944845.py in <cell line: 0>()
#      55     menu()
#      56
# ---> 57     pilihan_menu = int(input("Masukkan pilihan menu [1-5] : "))
#      58
#      59     if pilihan_menu == 1:
#
# ...
